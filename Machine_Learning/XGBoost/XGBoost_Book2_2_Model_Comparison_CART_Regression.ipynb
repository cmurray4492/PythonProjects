# %% [markdown]
# # XGBoost Book Model Comparison CART Regression

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, root_mean_squared_error, mean_squared_error
from sklearn.tree import DecisionTreeRegressor

# %%
# Load dataset
housingX, housingy = datasets.fetch_california_housing(return_X_y=True, as_frame=True)

# %%
housingX.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
housingy.head()
# Out:
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: MedHouseVal, dtype: float64

# %%
housingX.shape
# Out:
# (20640, 8)

# %%
housingX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %%
housingX.describe().T
# Out:
#               count         mean          std         min         25%  \
# MedInc      20640.0     3.870671     1.899822    0.499900    2.563400
# HouseAge    20640.0    28.639486    12.585558    1.000000   18.000000
# AveRooms    20640.0     5.429000     2.474173    0.846154    4.440716
# AveBedrms   20640.0     1.096675     0.473911    0.333333    1.006079
# Population  20640.0  1425.476744  1132.462122    3.000000  787.000000
# AveOccup    20640.0     3.070655    10.386050    0.692308    2.429741
# Latitude    20640.0    35.631861     2.135952   32.540000   33.930000
# Longitude   20640.0  -119.569704     2.003532 -124.350000 -121.800000
#
#                     50%          75%           max
# MedInc         3.534800     4.743250     15.000100
# HouseAge      29.000000    37.000000     52.000000
# AveRooms       5.229129     6.052381    141.909091
# AveBedrms      1.048780     1.099526     34.066667
# Population  1166.000000  1725.000000  35682.000000
# ...

# %% [markdown]
# ## EDA

# %%
#plt.figure(figsize=(18,10))
plt.figure(figsize=(8,8), dpi=250)
sns.set_palette("bright")
sns.displot(data=housingy, kind='hist');

# %%
housingxy = pd.concat([housingy, housingX], axis=1)
graphxy = sns.pairplot(housingxy)

# %%
plt.figure(figsize=(8,8), dpi=250)
sns.heatmap(data=housingxy.corr(), cmap='coolwarm', annot=True, vmax=1, vmin=-1, fmt='.2f');

# %% [markdown]
# ## Data Prep

# %%
X_train, X_test, y_train, y_test = train_test_split(housingX, housingy, test_size=0.2, random_state=17)

# %% [markdown]
# ## Make and Train Model

# %%
housing_CART = DecisionTreeRegressor()
housing_CART_regression = DecisionTreeRegressor().fit(X_train, y_train)

# %%
housing_cart_ypred = housing_CART_regression.predict(X_test)

# %%
housing_cart_rmse = root_mean_squared_error(y_true=y_test, y_pred = housing_cart_ypred)
print("Linear Regression RMSE is {0:.2f} ".format(housing_cart_rmse))
# Out:
# Linear Regression RMSE is 0.72

# %%
housing_cart_r2 = housing_CART_regression.score(X_test, y_test)
print("Linear RAegression R2 is {0:.2f}".format(housing_cart_r2))
# Out:
# Linear RAegression R2 is 0.61

# %%
plt.figure(figsize=(8,8), dpi=250)
sns.regplot(x=y_test, y=housing_cart_ypred, scatter_kws={"color":"blue"}, line_kws={"color":"yellow"});
